# %%
import numpy as np

# %%
import matplotlib as plt

# %%
import pandas as pd

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
Paragraph = '''The U.S. national security apparatus has cautioned that one avenue for retaliation Iran is likely to pursue is launching offensive cyber attacks targeting the U.S. public and private sectors. The day after Soleimani’s killing, the Department of Homeland Security (DHS) issued a bulletin warning that while it did not have information about an imminent attack, “Iran maintains a robust cyber program and can execute cyber attacks against the United States. Iran is capable, at a minimum, of carrying out attacks with temporary disruptive effects against critical infrastructure in the United States.” Such an attack could further “come with little or no warning.” Several days later, the Cybersecurity and Infrastructure Security Agency (CISA) within DHS issued an alert to stakeholders in the U.S. cybersecurity community recommending a heightened state of awareness and increased organizational vigilance, urging cybersecurity personnel to immediately flag "any known Iranian indicators of compromise and tactics, techniques, and procedures.”. The FBI similarly issued an advisory, obtained by Cyberscoop, to U.S. companies on January 9, 2020, assessing that Iranian hackers could use “a range of computer network operations against U.S.-based networks in retaliation for last week’s strikes against Iranian military leadership.” The FBI advisory noted that there had been an uptick in Iranian “cyber reconnaissance activity” since the Soleimani killing and offered technical advice to companies on thwarting Iranian efforts to exploit vulnerabilities in virtual private network (VPN) applications, which Iran has historically used to gain a foothold in computer networks allowing it to monitor, exfiltrate, and potentially destroy sensitive data. The FBI and DHS advisories echoed assessments issued by the U.S. intelligence community for several years, warning of Iran’s determination and ability to launch offensive cyber attacks against the U.S. and its allies. The 2018 Worldwide Threat Assessment of the U.S. Intelligence Community concluded that Iran “will continue working to penetrate U.S. and Allied networks for espionage and to position itself for potential future cyber attacks.” The assessment further warned that Iran is growing increasingly aggressive and will only be further emboldened absent significant push back against its malign cyber activities. According to the assessment, “The use of cyber attacks as a foreign policy tool outside of military conflict has been mostly limited to sporadic lower-level attacks. Russia, Iran, and North Korea, however, are testing more aggressive cyber attacks that pose growing threats to the United States and US partners.” The 2019 Worldwide Threat Assessment noted that the Iranian cyber threat had entered a new phase, with Iran increasingly focused on deploying “cyber attack capabilities that would enable attacks against critical infrastructure in the United States and allied countries.” At this point, Iranian cyber attacks are capable of "localized, temporary disruptive effects – such as disrupting a large company’s corporate networks for days to weeks.” The 2020 Worldwide Threat Assessment found that the Iranian cyber threat has advanced further, as Iran has now acquired “the ability to conduct attacks on critical infrastructure, as well as to conduct influence and espionage activities.”. The mounting concerns over an Iranian cyber attack reflect the considerable investment Iran has made in advancing its cyber warfare capabilities over the past decade. In 2010, over 15 Iranian nuclear facilities were targeted by the Stuxnet computer virus, a worm jointly developed by the U.S. and Israel that destroyed nearly 1000 centrifuges. The attack exposed the weakness of Iran’s cyber defenses, leading Iran to accelerate the advancement of offensive and defensive cyber warfare capabilities. By March 2012, Iran created a “cyber command” known as the Supreme Council of Cyberspace, comprised of senior military and intelligence officials. The council acts as a unified command tasked with coordinating Iran’s cybersecurity and plotting out of offensive and retaliatory cyber operations.'''

# %%
sentences = sent_tokenize(Paragraph)

# %%
for sentence in sentences:
    print(sentence)
# Out:
# The U.S. national security apparatus has cautioned that one avenue for retaliation Iran is likely to pursue is launching offensive cyber attacks targeting the U.S. public and private sectors.
# The day after Soleimani’s killing, the Department of Homeland Security (DHS) issued a bulletin warning that while it did not have information about an imminent attack, “Iran maintains a robust cyber program and can execute cyber attacks against the United States.
# Iran is capable, at a minimum, of carrying out attacks with temporary disruptive effects against critical infrastructure in the United States.” Such an attack could further “come with little or no warning.” Several days later, the Cybersecurity and Infrastructure Security Agency (CISA) within DHS issued an alert to stakeholders in the U.S. cybersecurity community recommending a heightened state of awareness and increased organizational vigilance, urging cybersecurity personnel to immediately flag "any known Iranian indicators of compromise and tactics, techniques, and procedures.”.
# The FBI similarly issued an advisory, obtained by Cyberscoop, to U.S. companies on January 9, 2020, assessing that Iranian hackers could use “a range of computer network operations against U.S.-based networks in retaliation for last week’s strikes against Iranian military leadership.” The FBI advisory noted that there had been an uptick in Iranian “cyber reconnaissance activity” since the Soleimani killing and offered technical advice to companies on thwarting Iranian efforts to exploit vulnerabilities in virtual private network (VPN) applications, which Iran has historically used to gain a foothold in computer networks allowing it to monitor, exfiltrate, and potentially destroy sensitive data.
# The FBI and DHS advisories echoed assessments issued by the U.S. intelligence community for several years, warning of Iran’s determination and ability to launch offensive cyber attacks against the U.S. and its allies.
# The 2018 Worldwide Threat Assessment of the U.S. Intelligence Community concluded that Iran “will continue working to penetrate U.S. and Allied networks for espionage and to position itself for potential future cyber attacks.” The assessment further warned that Iran is growing increasingly aggressive and will only be further emboldened absent significant push back against its malign cyber activities.
# According to the assessment, “The use of cyber attacks as a foreign policy tool outside of military conflict has been mostly limited to sporadic lower-level attacks.
# Russia, Iran, and North Korea, however, are testing more aggressive cyber attacks that pose growing threats to the United States and US partners.” The 2019 Worldwide Threat Assessment noted that the Iranian cyber threat had entered a new phase, with Iran increasingly focused on deploying “cyber attack capabilities that would enable attacks against critical infrastructure in the United States and allied countries.” At this point, Iranian cyber attacks are capable of "localized, temporary disruptive effects – such as disrupting a large company’s corporate networks for days to weeks.” The 2020 Worldwide Threat Assessment found that the Iranian cyber threat has advanced further, as Iran has now acquired “the ability to conduct attacks on critical infrastructure, as well as to conduct influence and espionage activities.”.
# The mounting concerns over an Iranian cyber attack reflect the considerable investment Iran has made in advancing its cyber warfare capabilities over the past decade.
# In 2010, over 15 Iranian nuclear facilities were targeted by the Stuxnet computer virus, a worm jointly developed by the U.S. and Israel that destroyed nearly 1000 centrifuges.
# The attack exposed the weakness of Iran’s cyber defenses, leading Iran to accelerate the advancement of offensive and defensive cyber warfare capabilities.
# By March 2012, Iran created a “cyber command” known as the Supreme Council of Cyberspace, comprised of senior military and intelligence officials.
# The council acts as a unified command tasked with coordinating Iran’s cybersecurity and plotting out of offensive and retaliatory cyber operations.

# %%
tokens = word_tokenize(Paragraph)

# %%
print(tokens)
# Out:
# ['The', 'U.S.', 'national', 'security', 'apparatus', 'has', 'cautioned', 'that', 'one', 'avenue', 'for', 'retaliation', 'Iran', 'is', 'likely', 'to', 'pursue', 'is', 'launching', 'offensive', 'cyber', 'attacks', 'targeting', 'the', 'U.S.', 'public', 'and', 'private', 'sectors', '.', 'The', 'day', 'after', 'Soleimani', '’', 's', 'killing', ',', 'the', 'Department', 'of', 'Homeland', 'Security', '(', 'DHS', ')', 'issued', 'a', 'bulletin', 'warning', 'that', 'while', 'it', 'did', 'not', 'have', 'information', 'about', 'an', 'imminent', 'attack', ',', '“', 'Iran', 'maintains', 'a', 'robust', 'cyber', 'program', 'and', 'can', 'execute', 'cyber', 'attacks', 'against', 'the', 'United', 'States', '.', 'Iran', 'is', 'capable', ',', 'at', 'a', 'minimum', ',', 'of', 'carrying', 'out', 'attacks', 'with', 'temporary', 'disruptive', 'effects', 'against', 'critical', 'infrastructure', 'in', 'the', 'United', 'States.', '”', 'Such', 'an', 'attack', 'could', 'further', '“', 'come', 'with', 'little', 'or', 'no', 'warning.', '”', 'Several', 'days', 'later', ',', 'the', 'Cybersecurity', 'and', 'Infrastructure', 'Security', 'Agency', '(', 'CISA', ')', 'within', 'DHS', 'issued', 'an', 'alert', 'to', 'stakeholders', 'in', 'the', 'U.S.', 'cybersecurity', 'community', 'recommending', 'a', 'heightened', 'state', 'of', 'awareness', 'and', 'increased', 'organizational', 'vigilance', ',', 'urging', 'cybersecurity', 'personnel', 'to', 'immediately', 'flag', '``', 'any', 'known', 'Iranian', 'indicators', 'of', 'compromise', 'and', 'tactics', ',', 'techniques', ',', 'and', 'procedures.', '”', '.', 'The', 'FBI', 'similarly', 'issued', 'an', 'advisory', ',', 'obtained', 'by', 'Cyberscoop', ',', 'to', 'U.S.', 'companies', 'on', 'January', '9', ',', '2020', ',', 'assessing', 'that', 'Iranian', 'hackers', 'could', 'use', '“', 'a', 'range', 'of', 'computer', 'network', 'operations', 'against', 'U.S.-based', 'networks', 'in', 'retaliation', 'for', 'last', 'week', '’', 's', 'strikes', 'against', 'Iranian', 'military', 'leadership.', '”', 'The', 'FBI', 'advisory', 'noted', 'that', 'there', 'had', 'been', 'an', 'uptick', 'in', 'Iranian', '“', 'cyber', 'reconnaissance', 'activity', '”', 'since', 'the', 'Soleimani', 'killing', 'and', 'offered', 'technical', 'advice', 'to', 'companies', 'on', 'thwarting', 'Iranian', 'efforts', 'to', 'exploit', 'vulnerabilities', 'in', 'virtual', 'private', 'network', '(', 'VPN', ')', 'applications', ',', 'which', 'Iran', 'has', 'historically', 'used', 'to', 'gain', 'a', 'foothold', 'in', 'computer', 'networks', 'allowing', 'it', 'to', 'monitor', ',', 'exfiltrate', ',', 'and', 'potentially', 'destroy', 'sensitive', 'data', '.', 'The', 'FBI', 'and', 'DHS', 'advisories', 'echoed', 'assessments', 'issued', 'by', 'the', 'U.S.', 'intelligence', 'community', 'for', 'several', 'years', ',', 'warning', 'of', 'Iran', '’', 's', 'determination', 'and', 'ability', 'to', 'launch', 'offensive', 'cyber', 'attacks', 'against', 'the', 'U.S.', 'and', 'its', 'allies', '.', 'The', '2018', 'Worldwide', 'Threat', 'Assessment', 'of', 'the', 'U.S.', 'Intelligence', 'Community', 'concluded', 'that', 'Iran', '“', 'will', 'continue', 'working', 'to', 'penetrate', 'U.S.', 'and', 'Allied', 'networks', 'for', 'espionage', 'and', 'to', 'position', 'itself', 'for', 'potential', 'future', 'cyber', 'attacks.', '”', 'The', 'assessment', 'further', 'warned', 'that', 'Iran', 'is', 'growing', 'increasingly', 'aggressive', 'and', 'will', 'only', 'be', 'further', 'emboldened', 'absent', 'significant', 'push', 'back', 'against', 'its', 'malign', 'cyber', 'activities', '.', 'According', 'to', 'the', 'assessment', ',', '“', 'The', 'use', 'of', 'cyber', 'attacks', 'as', 'a', 'foreign', 'policy', 'tool', 'outside', 'of', 'military', 'conflict', 'has', 'been', 'mostly', 'limited', 'to', 'sporadic', 'lower-level', 'attacks', '.', 'Russia', ',', 'Iran', ',', 'and', 'North', 'Korea', ',', 'however', ',', 'are', 'testing', 'more', 'aggressive', 'cyber', 'attacks', 'that', 'pose', 'growing ...

# %%
import string

# %%
from nltk.tokenize import word_tokenize

# %%
tokens = word_tokenize(Paragraph)

# %%
tokens_without_punct = [token for token in tokens if token not in string.punctuation]

# %%
Paragraph_without_punct = ' '.join(tokens_without_punct)

# %%
print("Original text:", Paragraph)
# Out:
# Original text: The U.S. national security apparatus has cautioned that one avenue for retaliation Iran is likely to pursue is launching offensive cyber attacks targeting the U.S. public and private sectors. The day after Soleimani’s killing, the Department of Homeland Security (DHS) issued a bulletin warning that while it did not have information about an imminent attack, “Iran maintains a robust cyber program and can execute cyber attacks against the United States. Iran is capable, at a minimum, of carrying out attacks with temporary disruptive effects against critical infrastructure in the United States.” Such an attack could further “come with little or no warning.” Several days later, the Cybersecurity and Infrastructure Security Agency (CISA) within DHS issued an alert to stakeholders in the U.S. cybersecurity community recommending a heightened state of awareness and increased organizational vigilance, urging cybersecurity personnel to immediately flag "any known Iranian indicators of compromise and tactics, techniques, and procedures.”. The FBI similarly issued an advisory, obtained by Cyberscoop, to U.S. companies on January 9, 2020, assessing that Iranian hackers could use “a range of computer network operations against U.S.-based networks in retaliation for last week’s strikes against Iranian military leadership.” The FBI advisory noted that there had been an uptick in Iranian “cyber reconnaissance activity” since the Soleimani killing and offered technical advice to companies on thwarting Iranian efforts to exploit vulnerabilities in virtual private network (VPN) applications, which Iran has historically used to gain a foothold in computer networks allowing it to monitor, exfiltrate, and potentially destroy sensitive data. The FBI and DHS advisories echoed assessments issued by the U.S. intelligence community for several years, warning of Iran’s determination and ability to launch offensive cyber attacks against the U.S. and its allies. The 2018 Worldwide Threat Assessment of the U.S. Intelligence Community concluded that Iran “will continue working to penetrate U.S. and Allied networks for espionage and to position itself for potential future cyber attacks.” The assessment further warned that Iran is growing increasingly aggressive and will only be further emboldened absent significant push back against its malign cyber activities. According to the assessment, “The use of cyber attacks as a foreign policy tool outside of military conflict has been mostly limited to sporadic lower-level attacks. Russia, Iran, and North Korea, however, are testing more aggressive cyber attacks that pose growing threats to the United States and US partners.” The 2019 Worldwide Threat Assessment noted that the Iranian cyber threat had entered a new phase, with Iran increasingly focused on deploying “cyber attack capabilities that would enable attacks against critical infrastructure in the United States and allied countries.” At this point, Iranian cyber attacks are capable of "localized, temporary disruptive effects – such as disrupting a large company’s corporate networks for days to weeks.” The 2020 Worldwide Threat Assessment found that the Iranian cyber threat has advanced further, as Iran has now acquired “the ability to conduct attacks on critical infrastructure, as well as to conduct influence and espionage activities.”. The mounting concerns over an Iranian cyber attack reflect the considerable investment Iran has made in advancing its cyber warfare capabilities over the past decade. In 2010, over 15 Iranian nuclear facilities were targeted by the Stuxnet computer virus, a worm jointly developed by the U.S. and Israel that destroyed nearly 1000 centrifuges. The attack exposed the weakness of Iran’s cyber defenses, leading Iran to accelerate the advancement of offensive and defensive cyber warfare capabilities. By March 2012, Iran created a “cyber command” known as the Supreme Council of Cyberspace, comprised of senior military  ...

# %%
print("Paragraph without punctuation:", Paragraph_without_punct)
# Out:
# Paragraph without punctuation: The U.S. national security apparatus has cautioned that one avenue for retaliation Iran is likely to pursue is launching offensive cyber attacks targeting the U.S. public and private sectors The day after Soleimani ’ s killing the Department of Homeland Security DHS issued a bulletin warning that while it did not have information about an imminent attack “ Iran maintains a robust cyber program and can execute cyber attacks against the United States Iran is capable at a minimum of carrying out attacks with temporary disruptive effects against critical infrastructure in the United States. ” Such an attack could further “ come with little or no warning. ” Several days later the Cybersecurity and Infrastructure Security Agency CISA within DHS issued an alert to stakeholders in the U.S. cybersecurity community recommending a heightened state of awareness and increased organizational vigilance urging cybersecurity personnel to immediately flag `` any known Iranian indicators of compromise and tactics techniques and procedures. ” The FBI similarly issued an advisory obtained by Cyberscoop to U.S. companies on January 9 2020 assessing that Iranian hackers could use “ a range of computer network operations against U.S.-based networks in retaliation for last week ’ s strikes against Iranian military leadership. ” The FBI advisory noted that there had been an uptick in Iranian “ cyber reconnaissance activity ” since the Soleimani killing and offered technical advice to companies on thwarting Iranian efforts to exploit vulnerabilities in virtual private network VPN applications which Iran has historically used to gain a foothold in computer networks allowing it to monitor exfiltrate and potentially destroy sensitive data The FBI and DHS advisories echoed assessments issued by the U.S. intelligence community for several years warning of Iran ’ s determination and ability to launch offensive cyber attacks against the U.S. and its allies The 2018 Worldwide Threat Assessment of the U.S. Intelligence Community concluded that Iran “ will continue working to penetrate U.S. and Allied networks for espionage and to position itself for potential future cyber attacks. ” The assessment further warned that Iran is growing increasingly aggressive and will only be further emboldened absent significant push back against its malign cyber activities According to the assessment “ The use of cyber attacks as a foreign policy tool outside of military conflict has been mostly limited to sporadic lower-level attacks Russia Iran and North Korea however are testing more aggressive cyber attacks that pose growing threats to the United States and US partners. ” The 2019 Worldwide Threat Assessment noted that the Iranian cyber threat had entered a new phase with Iran increasingly focused on deploying “ cyber attack capabilities that would enable attacks against critical infrastructure in the United States and allied countries. ” At this point Iranian cyber attacks are capable of `` localized temporary disruptive effects – such as disrupting a large company ’ s corporate networks for days to weeks. ” The 2020 Worldwide Threat Assessment found that the Iranian cyber threat has advanced further as Iran has now acquired “ the ability to conduct attacks on critical infrastructure as well as to conduct influence and espionage activities. ” The mounting concerns over an Iranian cyber attack reflect the considerable investment Iran has made in advancing its cyber warfare capabilities over the past decade In 2010 over 15 Iranian nuclear facilities were targeted by the Stuxnet computer virus a worm jointly developed by the U.S. and Israel that destroyed nearly 1000 centrifuges The attack exposed the weakness of Iran ’ s cyber defenses leading Iran to accelerate the advancement of offensive and defensive cyber warfare capabilities By March 2012 Iran created a “ cyber command ” known as the Supreme Council of Cyberspace comprised of senior militar ...

# %%
from nltk.stem import PorterStemmer

# %%
porter_stemmer = PorterStemmer()

# %%
print("Original Paragraph:", Paragraph)
# Out:
# Original Paragraph: The U.S. national security apparatus has cautioned that one avenue for retaliation Iran is likely to pursue is launching offensive cyber attacks targeting the U.S. public and private sectors. The day after Soleimani’s killing, the Department of Homeland Security (DHS) issued a bulletin warning that while it did not have information about an imminent attack, “Iran maintains a robust cyber program and can execute cyber attacks against the United States. Iran is capable, at a minimum, of carrying out attacks with temporary disruptive effects against critical infrastructure in the United States.” Such an attack could further “come with little or no warning.” Several days later, the Cybersecurity and Infrastructure Security Agency (CISA) within DHS issued an alert to stakeholders in the U.S. cybersecurity community recommending a heightened state of awareness and increased organizational vigilance, urging cybersecurity personnel to immediately flag "any known Iranian indicators of compromise and tactics, techniques, and procedures.”. The FBI similarly issued an advisory, obtained by Cyberscoop, to U.S. companies on January 9, 2020, assessing that Iranian hackers could use “a range of computer network operations against U.S.-based networks in retaliation for last week’s strikes against Iranian military leadership.” The FBI advisory noted that there had been an uptick in Iranian “cyber reconnaissance activity” since the Soleimani killing and offered technical advice to companies on thwarting Iranian efforts to exploit vulnerabilities in virtual private network (VPN) applications, which Iran has historically used to gain a foothold in computer networks allowing it to monitor, exfiltrate, and potentially destroy sensitive data. The FBI and DHS advisories echoed assessments issued by the U.S. intelligence community for several years, warning of Iran’s determination and ability to launch offensive cyber attacks against the U.S. and its allies. The 2018 Worldwide Threat Assessment of the U.S. Intelligence Community concluded that Iran “will continue working to penetrate U.S. and Allied networks for espionage and to position itself for potential future cyber attacks.” The assessment further warned that Iran is growing increasingly aggressive and will only be further emboldened absent significant push back against its malign cyber activities. According to the assessment, “The use of cyber attacks as a foreign policy tool outside of military conflict has been mostly limited to sporadic lower-level attacks. Russia, Iran, and North Korea, however, are testing more aggressive cyber attacks that pose growing threats to the United States and US partners.” The 2019 Worldwide Threat Assessment noted that the Iranian cyber threat had entered a new phase, with Iran increasingly focused on deploying “cyber attack capabilities that would enable attacks against critical infrastructure in the United States and allied countries.” At this point, Iranian cyber attacks are capable of "localized, temporary disruptive effects – such as disrupting a large company’s corporate networks for days to weeks.” The 2020 Worldwide Threat Assessment found that the Iranian cyber threat has advanced further, as Iran has now acquired “the ability to conduct attacks on critical infrastructure, as well as to conduct influence and espionage activities.”. The mounting concerns over an Iranian cyber attack reflect the considerable investment Iran has made in advancing its cyber warfare capabilities over the past decade. In 2010, over 15 Iranian nuclear facilities were targeted by the Stuxnet computer virus, a worm jointly developed by the U.S. and Israel that destroyed nearly 1000 centrifuges. The attack exposed the weakness of Iran’s cyber defenses, leading Iran to accelerate the advancement of offensive and defensive cyber warfare capabilities. By March 2012, Iran created a “cyber command” known as the Supreme Council of Cyberspace, comprised of senior mili ...

# %%
from nltk.corpus import stopwords

# %%
tokens = word_tokenize(Paragraph)

# %%
stop_words = set(stopwords.words('english'))

# %%
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

# %%
text_without_stopwords = ' '.join(filtered_tokens)

# %%
print("Original text:", Paragraph)
# Out:
# Original text: The U.S. national security apparatus has cautioned that one avenue for retaliation Iran is likely to pursue is launching offensive cyber attacks targeting the U.S. public and private sectors. The day after Soleimani’s killing, the Department of Homeland Security (DHS) issued a bulletin warning that while it did not have information about an imminent attack, “Iran maintains a robust cyber program and can execute cyber attacks against the United States. Iran is capable, at a minimum, of carrying out attacks with temporary disruptive effects against critical infrastructure in the United States.” Such an attack could further “come with little or no warning.” Several days later, the Cybersecurity and Infrastructure Security Agency (CISA) within DHS issued an alert to stakeholders in the U.S. cybersecurity community recommending a heightened state of awareness and increased organizational vigilance, urging cybersecurity personnel to immediately flag "any known Iranian indicators of compromise and tactics, techniques, and procedures.”. The FBI similarly issued an advisory, obtained by Cyberscoop, to U.S. companies on January 9, 2020, assessing that Iranian hackers could use “a range of computer network operations against U.S.-based networks in retaliation for last week’s strikes against Iranian military leadership.” The FBI advisory noted that there had been an uptick in Iranian “cyber reconnaissance activity” since the Soleimani killing and offered technical advice to companies on thwarting Iranian efforts to exploit vulnerabilities in virtual private network (VPN) applications, which Iran has historically used to gain a foothold in computer networks allowing it to monitor, exfiltrate, and potentially destroy sensitive data. The FBI and DHS advisories echoed assessments issued by the U.S. intelligence community for several years, warning of Iran’s determination and ability to launch offensive cyber attacks against the U.S. and its allies. The 2018 Worldwide Threat Assessment of the U.S. Intelligence Community concluded that Iran “will continue working to penetrate U.S. and Allied networks for espionage and to position itself for potential future cyber attacks.” The assessment further warned that Iran is growing increasingly aggressive and will only be further emboldened absent significant push back against its malign cyber activities. According to the assessment, “The use of cyber attacks as a foreign policy tool outside of military conflict has been mostly limited to sporadic lower-level attacks. Russia, Iran, and North Korea, however, are testing more aggressive cyber attacks that pose growing threats to the United States and US partners.” The 2019 Worldwide Threat Assessment noted that the Iranian cyber threat had entered a new phase, with Iran increasingly focused on deploying “cyber attack capabilities that would enable attacks against critical infrastructure in the United States and allied countries.” At this point, Iranian cyber attacks are capable of "localized, temporary disruptive effects – such as disrupting a large company’s corporate networks for days to weeks.” The 2020 Worldwide Threat Assessment found that the Iranian cyber threat has advanced further, as Iran has now acquired “the ability to conduct attacks on critical infrastructure, as well as to conduct influence and espionage activities.”. The mounting concerns over an Iranian cyber attack reflect the considerable investment Iran has made in advancing its cyber warfare capabilities over the past decade. In 2010, over 15 Iranian nuclear facilities were targeted by the Stuxnet computer virus, a worm jointly developed by the U.S. and Israel that destroyed nearly 1000 centrifuges. The attack exposed the weakness of Iran’s cyber defenses, leading Iran to accelerate the advancement of offensive and defensive cyber warfare capabilities. By March 2012, Iran created a “cyber command” known as the Supreme Council of Cyberspace, comprised of senior military  ...

# %%
print("Text without stop words:", text_without_stopwords)
# Out:
# Text without stop words: U.S. national security apparatus cautioned one avenue retaliation Iran likely pursue launching offensive cyber attacks targeting U.S. public private sectors . day Soleimani ’ killing , Department Homeland Security ( DHS ) issued bulletin warning information imminent attack , “ Iran maintains robust cyber program execute cyber attacks United States . Iran capable , minimum , carrying attacks temporary disruptive effects critical infrastructure United States. ” attack could “ come little warning. ” Several days later , Cybersecurity Infrastructure Security Agency ( CISA ) within DHS issued alert stakeholders U.S. cybersecurity community recommending heightened state awareness increased organizational vigilance , urging cybersecurity personnel immediately flag `` known Iranian indicators compromise tactics , techniques , procedures. ” . FBI similarly issued advisory , obtained Cyberscoop , U.S. companies January 9 , 2020 , assessing Iranian hackers could use “ range computer network operations U.S.-based networks retaliation last week ’ strikes Iranian military leadership. ” FBI advisory noted uptick Iranian “ cyber reconnaissance activity ” since Soleimani killing offered technical advice companies thwarting Iranian efforts exploit vulnerabilities virtual private network ( VPN ) applications , Iran historically used gain foothold computer networks allowing monitor , exfiltrate , potentially destroy sensitive data . FBI DHS advisories echoed assessments issued U.S. intelligence community several years , warning Iran ’ determination ability launch offensive cyber attacks U.S. allies . 2018 Worldwide Threat Assessment U.S. Intelligence Community concluded Iran “ continue working penetrate U.S. Allied networks espionage position potential future cyber attacks. ” assessment warned Iran growing increasingly aggressive emboldened absent significant push back malign cyber activities . According assessment , “ use cyber attacks foreign policy tool outside military conflict mostly limited sporadic lower-level attacks . Russia , Iran , North Korea , however , testing aggressive cyber attacks pose growing threats United States US partners. ” 2019 Worldwide Threat Assessment noted Iranian cyber threat entered new phase , Iran increasingly focused deploying “ cyber attack capabilities would enable attacks critical infrastructure United States allied countries. ” point , Iranian cyber attacks capable `` localized , temporary disruptive effects – disrupting large company ’ corporate networks days weeks. ” 2020 Worldwide Threat Assessment found Iranian cyber threat advanced , Iran acquired “ ability conduct attacks critical infrastructure , well conduct influence espionage activities. ” . mounting concerns Iranian cyber attack reflect considerable investment Iran made advancing cyber warfare capabilities past decade . 2010 , 15 Iranian nuclear facilities targeted Stuxnet computer virus , worm jointly developed U.S. Israel destroyed nearly 1000 centrifuges . attack exposed weakness Iran ’ cyber defenses , leading Iran accelerate advancement offensive defensive cyber warfare capabilities . March 2012 , Iran created “ cyber command ” known Supreme Council Cyberspace , comprised senior military intelligence officials . council acts unified command tasked coordinating Iran ’ cybersecurity plotting offensive retaliatory cyber operations .

# %%
from wordcloud import WordCloud

# %%
import matplotlib.pyplot as plt

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(Paragraph)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Turn off the axis labels
plt.show()
